# %%
# %%bash
# pip install -qr https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt  # install dependencies

# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-11-1 Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
# Images
imgs = ['/content/imagenes/tattoo.jpg']  # batch of images

# %%
from PIL import Image
img = Image.open(r'/content/imagenes/tattoo.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=588x250 at 0x7F11B3F06A90>

# %%
# Inference
results = model(imgs)
# Results
results.print()
# Out:
# image 1/1: 250x588 (no detections)
# Speed: 12.1ms pre-process, 185.3ms inference, 0.9ms NMS per image at shape (1, 3, 288, 672)

# %%
# Results
results.print()
# Out:
# image 1/1: 735x735 (no detections)
# Speed: 27.8ms pre-process, 356.6ms inference, 0.6ms NMS per image at shape (1, 3, 640, 640)

# %%
results.save()  # or .show()
# Out:
# Saved 1 image to runs/detect/exp

# %%
results.xyxy[0]  # img1 predictions (tensor)
# Out:
# tensor([[8.68430e+01, 1.02138e+02, 1.30523e+03, 9.27037e+02, 3.13316e-01, 7.40000e+01]])

# %%
results.pandas().xyxy[0]  # img1 predictions (pandas)
# Out:
#         xmin        ymin        xmax        ymax  confidence  class   name
# 0  86.842957  102.137535  1305.22644  927.037354    0.313316     74  clock

# %%
from PIL import Image

# %%
img = Image.open(r'/content/imagenes/concesionaria.jpeg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-685bec427c60> in <module>
# ----> 1 img = Image.open(r'/content/imagenes/concesionaria.jpeg')
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/imagenes/concesionaria.jpeg'

# %%
cropped = img.crop((0.073616, 95.753120, 35.594677, 156.990234))

# %%
cropped
# Out:
# <PIL.Image.Image image mode=RGB size=36x61 at 0x7F9AD70A35D0>

# %% [markdown]
# Probando varias imagenes

# %%
import os

# %%
entries = os.listdir('/content/imagenes')
entries
# Out:
# ['avion.jpg', 'faro.png', 'interior.png', 'carro.jpg', 'concesionaria.jpeg']

# %%
folder_name = '/content/imagenes/'
full_entries_name = list(map(lambda orig_string: folder_name + orig_string, entries))
full_entries_name
# Out:
# ['/content/imagenes/avion.jpg',
#  '/content/imagenes/faro.png',
#  '/content/imagenes/interior.png',
#  '/content/imagenes/carro.jpg',
#  '/content/imagenes/concesionaria.jpeg']

# %%
# Inference
results = model(full_entries_name)

# %%
# Results
results.pandas().xyxy[0]  # img1 predictions (pandas)
# Out:
#         xmin        ymin        xmax         ymax  confidence  class      name
# 0  139.30603  358.376129  1746.79834  1543.654297    0.681414      4  airplane

# %%
# Results
results.pandas().xyxy[1]  # img2 predictions (pandas)
# Out:
#         xmin       ymin        xmax        ymax  confidence  class name
# 0  61.108356  42.907829  336.264282  245.614868    0.656455      5  bus

# %%
# Results
results.pandas().xyxy[2]  # img3 predictions (pandas)
# Out:
#         xmin       ymin        xmax        ymax  confidence  class name
# 0  70.248314  74.157066  391.532349  261.595795    0.540916      2  car

# %%
# Results
results.pandas().xyxy[3]  # img4 predictions (pandas)
# Out:
#         xmin       ymin       xmax       ymax  confidence  class name
# 0  43.991707  41.711613  444.36557  258.47934    0.743772      2  car

# %%
# Results
results.pandas().xyxy[4]  # img5 predictions (pandas)
# Out:
#          xmin       ymin        xmax        ymax  confidence  class   name
# 0    0.066379  95.723289   35.567375  157.271194    0.880371      2    car
# 1   12.182815  81.402069  118.474945  134.254318    0.855721      2    car
# 2  146.957138  81.005859  244.470139  149.118744    0.769789      2    car
# 3  234.879150  81.656876  265.942017  116.115547    0.628859      2    car
# 4  146.989410  81.360214  245.192200  149.475800    0.573096      7  truck
# 5  124.211731  83.230553  163.676743  112.854469    0.452133      2    car
# 6  124.499466  83.226341  163.714996  113.324509    0.392358      7  truck
# 7  152.664551  81.766922  175.912643  106.270012    0.296637      2    car
